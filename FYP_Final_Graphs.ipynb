# %%
import seaborn as sns
import os
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %%
# x-coordinates of left sides of bars  
left = [1, 2, 3, 4, 5] 
  
# heights of bars 
height = [54.21 , 55.53, 55.53 , 55.53, 55.79] 
  
# labels for bars 
tick_label = ['Softmax', 'Softplus', 'Selu', 'Elu',' Relu'] 
  
# plotting a bar chart 
plot = plt.bar(left, height , tick_label = tick_label, 
        width = 0.7, color = ['gray']) 

for value in plot:
    height = value.get_height()
    plt.text(value.get_x() + value.get_width()/2.,
             1.002*height,'%s' % float(height), ha='center', va='bottom')


plt.ylim(54, 56.25)

plt.yticks([54.0, 54.5, 55.0, 55.5, 56])
# naming the x-axis 
plt.xlabel('Activation Function', labelpad = 10) 
# naming the y-axis 
plt.ylabel('Accuracy', labelpad = 10) 
# plot title 

# save figure as png
# plt.savefig('Activation_Function.png', bbox_inches='tight')
  
# function to show the plot 
plt.show()

# %%
# x-coordinates of left sides of bars  
left = [2, 4, 6, 8, 10, 12] 
  
# heights of bars 
height = [54.08 , 55.66, 46.45 , 55.13, 55.26, 55.79] 
  
# labels for bars 
tick_label = ['SGD', 'RMSprop', 'Adadelta', 'Adamax','Nadam', 'Adam'] 
  
# plotting a bar chart 
plot = plt.bar(left, height , tick_label = tick_label, 
        width = 1.5, color = ['gray']) 

for value in plot:
    height = value.get_height()
    plt.text(value.get_x() + value.get_width()/2.,
             1.002*height,'%s' % float(height), ha='center', va='bottom')


plt.ylim(46, 58)

# plt.yticks([54.0, 54.5, 55.0, 55.5, 56])
# naming the x-axis 
plt.xlabel('Optimiser', labelpad = 10) 
# naming the y-axis 
plt.ylabel('Accuracy', labelpad = 10) 
# plot title 

# save figure as png
# plt.savefig('Optimiser.png', bbox_inches='tight')
  
# function to show the plot 
plt.show()

# %%
# x-coordinates of left sides of bars  
left = [2, 5, 8, 11, 14] 
  
# heights of bars 
height = [55.39 , 55.53, 55.53 , 55.53, 55.79] 
  
# labels for bars 
tick_label = ['MeanSquared', 'Huber', 'KLDivergence', 'Poisson','Crossentropy'] 
  
# plotting a bar chart 
plot = plt.bar(left, height , tick_label = tick_label, 
        width = 2, color = ['gray']) 

for value in plot:
    height = value.get_height()
    plt.text(value.get_x() + value.get_width()/2.,
             1.002*height,'%s' % float(height), ha='center', va='bottom')


plt.ylim(54, 56.25)

plt.yticks([54.0, 54.5, 55.0, 55.5, 56])
# naming the x-axis 
plt.xlabel('Loss Function', labelpad = 10) 
# naming the y-axis 
plt.ylabel('Accuracy', labelpad = 10) 
# plot title 

# save figure as png
# plt.savefig('Loss_Function.png', bbox_inches='tight')
  
# function to show the plot 
plt.show()

# %%
# x-coordinates of left sides of bars  
left = [2, 5, 8, 11, 14, 17] 
  
# heights of bars 

# Elo with other features included
# height = [55.79 , 55.56, 55.92 , 55.79, 55, 55.36] 

height = [55.53 , 55.13, 55.69 , 54.74, 55.17, 53.95] 
# Elo as the only predictor
# k = 32 and MOV - 55.39

# k = 256 - 53.95
# k = 128 - 55.17
# k = 64 - 54.74
# k = 32 - 55.69
# k = 16 - 55.13
# k = 8 - 55.53

# k = 32 and no soft reset - 55.39

# labels for bars 
tick_label = ['8', '16', '32', '64','128','256'] 

# plotting a bar chart 
plot = plt.bar(left, height , tick_label = tick_label, 
        width = 2, color = ['gray']) 

for value in plot:
    height = value.get_height()
    plt.text(value.get_x() + value.get_width()/2.,
             1.002*height,'%s' % float(height), ha='center', va='bottom')


plt.ylim(53, 56.35)

# plt.yticks([54.0, 54.5, 55.0, 55.5, 56])
# naming the x-axis 
plt.xlabel('Elo K value', labelpad = 10) 
# naming the y-axis 
plt.ylabel('Accuracy', labelpad = 10) 
# plot title 

# save figure as png
# plt.savefig('Elo_K_Value1.png', bbox_inches='tight')
  
# function to show the plot 
plt.show()

# %%
# x-coordinates of left sides of bars  
left = [2, 5, 8, 11, 14, 17, 20] 
  
# heights of bars 
# Height with 
# height = [55.26 , 55.39, 55.92 , 56.05, 55.32] 


height = [49.08 , 52.63, 53.29 , 51.84, 52.50, 53.42, 52.24] 
# As single predictor
# X = 1 - 49.08
# X = 2 - 52.63
# X = 3 - 53.29
# X = 4 - 51.84
# X = 5 - 52.50
# X = 6 - 53.42
# X = 7 - 52.24

# labels for bars 
tick_label = ['1','2', '3', '4', '5','6','7'] 
  
# plotting a bar chart 
plot = plt.bar(left, height , tick_label = tick_label, 
        width = 2, color = ['gray']) 

for value in plot:
    height = value.get_height()
    plt.text(value.get_x() + value.get_width()/2.,
             1.002*height,'%s' % float(height), ha='center', va='bottom')


plt.ylim(48, 54.5)

# plt.yticks([55.0, 55.25,55.5, 55.75, 56, 56.25])
# naming the x-axis 
plt.xlabel('Number of Games', labelpad = 10) 
# naming the y-axis 
plt.ylabel('Accuracy', labelpad = 10) 
# plot title 

# save figure as png
# plt.savefig('form2.png', bbox_inches='tight')
  
# function to show the plot 
plt.show()

# %%
# x-coordinates of left sides of bars  
left = [2, 4, 6, 8] 
  
# heights of bars 
# Height with 
# height = [55.26 , 55.39, 55.92 , 56.05, 55.32] 


height = [52.89, 53.95, 49.08, 51.71] 


# labels for bars 
tick_label = ['Goal Difference','Points', 'Shots', 'Shots Faced'] 
  
# plotting a bar chart 
plot = plt.bar(left, height , tick_label = tick_label, 
        width = 1.3, color = ['gray']) 

for value in plot:
    height = value.get_height()
    plt.text(value.get_x() + value.get_width()/2.,
             1.002*height,'%s' % float(height), ha='center', va='bottom')


plt.ylim(48, 55.5)

plt.yticks([46, 48, 50, 52, 54])
# naming the x-axis 
plt.xlabel('Match Statistics', labelpad = 10) 
# naming the y-axis 
plt.ylabel('Accuracy', labelpad = 10) 
# plot title 

# save figure as png
plt.savefig('matchStatistics.png', bbox_inches='tight')
  
# function to show the plot 
plt.show()
